# %% [markdown]
# # Sentiment per state

# %%
# dependancies
import pandas as pd
import geopandas as gpd
import os
import matplotlib.pyplot as plt
import matplotlib as mpl
# %matplotlib inline
from scipy.stats import chi2_contingency
from sklearn.preprocessing import MinMaxScaler

# %%
loc_shape_file = "../datasets/states_21basic/states.shp"
loc_twitter = "../datasets/state_sen_summary_twitter_skl.pkl"
loc_movies = "../datasets/state_sen_summary_movie_skl.pkl"
loc_state = "../datasets/state_id.pkl"
loc_shape_file = "../datasets/states_21basic/states.shp"
loc_votes_file = "../datasets/election_totals.pkl"

# %% [markdown]
# ## Load in data
# ### Use loc_twitter for the twitter_sample training corpus and loc_movies for the IMDB movie training corpus

# %%
# Load in data
state_dataframe = gpd.read_file(loc_shape_file)

# Use loc_twitter for the twitter_sample training corpus and loc_movies for the IMDB movie training corpus
twitter_sen = pd.read_pickle(loc_twitter)
state_df = pd.read_pickle(loc_state)

# %%
twitter_score = twitter_sen.reset_index()
twitter_score.rename(columns={'id': 'count'}, inplace=True)
twitter_score.head()
# Out:
#      state Mentions sentiment  count
# 0  Alabama  clinton       neg    526
# 1  Alabama  clinton       pos    420
# 2  Alabama    trump       neg   1921
# 3  Alabama    trump       pos   2112
# 4   Alaska  clinton       neg    111

# %%
# Count number of positive/negative tweets
def score_function(sentiment, id_count):
    if sentiment == "neg":
        return - int(id_count)
    elif sentiment == "pos":
        return int(id_count)
    else:
        return None

# %%
twitter_score["sen_score"] = [score_function(x, y) for x,y in zip(twitter_score["sentiment"],twitter_score["count"])]

# %%
# Sum positive and negative tweets
twitter_states = twitter_score.groupby(["Mentions", "state"]).sum()

# Create relative scores by dividing by all tweets mentioning the candidate.
clinton =  twitter_states.loc["clinton"]
clinton["clinton_sen_score"] = clinton["sen_score"] / clinton["count"]

trump =  twitter_states.loc["trump"]
trump["trump_sen_score"] = trump["sen_score"] / trump["count"]

# %%
# Merge dataframes
tweet_counts = twitter_sen.groupby("state").sum()
tweet_counts.rename(columns={'id': 'count'}, inplace=True)
state_dataframe_tot = state_dataframe.merge(tweet_counts, left_on = "STATE_NAME", right_on = "state")
state_dataframe_c = state_dataframe_tot.merge(clinton.loc[:,"clinton_sen_score"], left_on = "STATE_NAME",
                                              right_on = "state")
state_sen_df = state_dataframe_c.merge(trump.loc[:,"trump_sen_score"], left_on = "STATE_NAME", 
                                       right_on = "state")
state_sen_df.drop(["DRAWSEQ","STATE_FIPS", "SUB_REGION", "STATE_ABBR"], axis =1, inplace = True)
state_sen_df.head()
# Out:
#      STATE_NAME                                           geometry  count  \
# 0        Hawaii  (POLYGON ((-160.0738033454681 22.0041773479577...   1596
# 1    Washington  (POLYGON ((-122.4020153103835 48.2252163723779...   7520
# 2       Montana  POLYGON ((-111.4754253002074 44.70216236909688...    434
# 3         Maine  (POLYGON ((-69.77727626137293 44.0741483685119...   2583
# 4  North Dakota  POLYGON ((-98.73043728833767 45.93827137024809...    282
#
#    clinton_sen_score  trump_sen_score
# 0          -0.105085        -0.156034
# 1          -0.067770        -0.030965
# 2           0.000000         0.000000
# 3          -0.024590        -0.038663
# 4           0.069767        -0.326531

# %%
# Plot tweet activity
_ = state_sen_df.plot(column='count',edgecolor='white', cmap='cool',
                        figsize=(30,20),scheme='equal_interval', k=10, legend=True)
_.axis('off')
plt.title("Amount of tweets per state", fontsize=30)
plt.show()

# %%
# Colormaps equal
col_min = min(trump["trump_sen_score"].min(), clinton["clinton_sen_score"].min())
col_max = max(trump["trump_sen_score"].max(), clinton["clinton_sen_score"].max())

_ = state_sen_df.plot(column='clinton_sen_score',edgecolor='white', cmap='seismic',
                        figsize=(30,20),scheme='equal_interval', k=10, legend=True,
                      norm=mpl.colors.Normalize(vmin=col_min, vmax=col_max))
_.axis('off')
plt.title("Sentiment of tweet mentioning Clinton per state", fontsize=30)
plt.show()

# %%
_ = state_sen_df.plot(column='trump_sen_score',edgecolor='white', cmap='seismic',
                        figsize=(30,20),scheme='equal_interval', k=10, legend=True,
                     norm=mpl.colors.Normalize(vmin=col_min, vmax=col_max))
_.axis('off')
plt.title("Sentiment of tweet mentioning Trump per state", fontsize=30)
plt.show()

# %%
votes = pd.read_pickle(loc_votes_file).pivot_table(values='candidate_percent',
                                                   index='state', columns='candidate')
votes.head()
# Out:
# candidate   Clinton, Hillary  Trump, Donald J.
# state
# Alabama             0.343579          0.620831
# Alaska              0.365509          0.512815
# Arizona             0.451260          0.486716
# Arkansas            0.336531          0.605741
# California          0.617264          0.316171

# %%
votes_map = state_sen_df.merge(votes, left_on = "STATE_NAME", right_on = "state", 
                               how = "right")
votes_map.head()
# Out:
#      STATE_NAME                                           geometry  count  \
# 0        Hawaii  (POLYGON ((-160.0738033454681 22.0041773479577...   1596
# 1    Washington  (POLYGON ((-122.4020153103835 48.2252163723779...   7520
# 2       Montana  POLYGON ((-111.4754253002074 44.70216236909688...    434
# 3         Maine  (POLYGON ((-69.77727626137293 44.0741483685119...   2583
# 4  North Dakota  POLYGON ((-98.73043728833767 45.93827137024809...    282
#
#    clinton_sen_score  trump_sen_score  Clinton, Hillary  Trump, Donald J.
# 0          -0.105085        -0.156034          0.609808          0.294397
# 1          -0.067770        -0.030965          0.525387          0.368327
# 2           0.000000         0.000000          0.359352          0.564662
# 3          -0.024590        -0.038663          0.463452          0.434767
# 4           0.069767        -0.326531          0.272267          0.629556

# %%
# votes_map["clinton_sen_scale"] = None
# votes_map["trump_sen_scale"] = None
# scaler = MinMaxScaler() 
# scaled_values = scaler.fit_transform(votes_map.loc[:, ["trump_sen_score","clinton_sen_score"]]) 
# votes_map.loc[:, ["trump_sen_scale","clinton_sen_scale"]] = scaled_values
# votes_map

# %%
votes_map["vector_sentiment"] =  votes_map["trump_sen_score"] - votes_map["clinton_sen_score"]
votes_map["vector_vote"] =  votes_map["Trump, Donald J."] - votes_map["Clinton, Hillary"]
votes_map.head()
# Out:
#      STATE_NAME                                           geometry  count  \
# 0        Hawaii  (POLYGON ((-160.0738033454681 22.0041773479577...   1596
# 1    Washington  (POLYGON ((-122.4020153103835 48.2252163723779...   7520
# 2       Montana  POLYGON ((-111.4754253002074 44.70216236909688...    434
# 3         Maine  (POLYGON ((-69.77727626137293 44.0741483685119...   2583
# 4  North Dakota  POLYGON ((-98.73043728833767 45.93827137024809...    282
#
#    clinton_sen_score  trump_sen_score  Clinton, Hillary  Trump, Donald J.  \
# 0          -0.105085        -0.156034          0.609808          0.294397
# 1          -0.067770        -0.030965          0.525387          0.368327
# 2           0.000000         0.000000          0.359352          0.564662
# 3          -0.024590        -0.038663          0.463452          0.434767
# 4           0.069767        -0.326531          0.272267          0.629556
#
#    vector_sentiment  vector_vote
# 0         -0.050949    -0.315411
# 1          0.036806    -0.157060
# 2          0.000000     0.205310
# 3         -0.014073    -0.028685
# 4         -0.396298     0.357289

# %%
votes_map.loc[:,["STATE_NAME","vector_sentiment","vector_vote"]]
# Out:
#               STATE_NAME  vector_sentiment  vector_vote
# 0                 Hawaii         -0.050949    -0.315411
# 1             Washington          0.036806    -0.157060
# 2                Montana          0.000000     0.205310
# 3                  Maine         -0.014073    -0.028685
# 4           North Dakota         -0.396298     0.357289
# 5           South Dakota         -0.113623     0.297933
# 6                Wyoming          0.096204     0.457695
# 7              Wisconsin         -0.065309     0.007643
# 8                  Idaho          0.025839     0.317694
# 9                Vermont          0.178587    -0.259634
# 10             Minnesota          0.016790    -0.015198
# 11                Oregon         -0.016128    -0.109778
# 12         New Hampshire         -0.103976    -0.003676
# 13                  Iowa          0.177912     0.094095
# 14         Massachusetts          0.015070    -0.267639
# 15              Nebraska          0.001514     0.250486
# 16              New York          0.010227    -0.222580
# 17          Pennsylvania          0.036285     0.007243
# 18           Connecticut         -0.028719    -0.136394
# 19          Rhode Island         -0.037334    -0.155085
# 20            New Jersey          0.001590    -0.141027
# 21               Indiana          0.031286     0.191652
# 22                Nevada          0.057038    -0.024171
# 23                  Utah          0.053613     0.180795
# 24            California         -0.005425    -0.301093
# 25                  Ohio         -0.015635     0.081296
# 26              Illinois          0.029807    -0.170636
# 27  District of Columbia         -0.062850    -0.864135
# 28              Delaware          0.148032    -0.114305
# 29         West Virginia         -0.018865     0.421536
# 30              Maryland         -0.070218    -0.264099
# 31              Colorado          0.047291    -0.049056
# 32              Kentucky         -0.023372     0.298375
# 33                Kansas         -0.021008     0.206022
# 34              Virginia          0.033060    -0.053237
# 35              Missouri          0.060918     0.186371
# 36               Arizona          0.081282     0.035456
# 37              Oklahoma          0.084172     0.363912
# 38        North Carolina          0.092051     0.036552
# 39             Tennessee          0.028902     0.260057
# 40                 Texas          0.059207     0.089994
# 41            New Mexico          0.013667    -0.082131
# 42               Alabama          0.159410     0.277251
# 43           Mississippi          0.007160     0.178262
# 44               Georgia          0.043018     0.051313
# 45        South Carolina          0.054652     0.142659
# 46              Arkansas          0.139372     0.269210
# 47             Louisiana          0.201701     0.196391
# 48               Florida          0.044945     0.011986
# 49              Michigan          0.021398     0.002230
# 50                Alaska          0.070800     0.147306

# %%
# Colormaps color
col_min = min(votes_map['vector_vote'])
col_max = max(votes_map['vector_vote'])

_ = votes_map.plot(column='vector_vote',edgecolor='white', cmap='seismic',
                        figsize=(30,20),scheme='equal_interval', k=10, legend=True,
                   norm=mpl.colors.Normalize(vmin=col_min, vmax=col_max))
_.axis('off')
plt.title("Percentage difference in vote (Trump is red)", fontsize=30)
plt.show()

# %%
votes_map[votes_map['vector_vote'] == col_max]
# Out:
#   STATE_NAME                                           geometry  count  \
# 6    Wyoming  POLYGON ((-104.0536152932953 41.69821836629923...    499
#
#    clinton_sen_score  trump_sen_score  Clinton, Hillary  Trump, Donald J.  \
# 6          -0.170068        -0.073864          0.216289          0.673984
#
#    vector_sentiment  vector_vote
# 6          0.096204     0.457695

# %%
# Colormaps equal
col_min = 0
col_max = 1

_ = votes_map.plot(column='vector_sentiment',edgecolor='white', cmap='seismic',
                        figsize=(30,20),scheme='equal_interval', k=10, legend=True)
_.axis('off')
plt.title("Difference in sentiment scores (more positive to Trump is red)", fontsize=30)
plt.show()

# %%
votes_map.loc[:,["vector_sentiment","vector_vote"]]
# Out:
#     vector_sentiment  vector_vote
# 0          -0.050949    -0.315411
# 1           0.036806    -0.157060
# 2           0.000000     0.205310
# 3          -0.014073    -0.028685
# 4          -0.396298     0.357289
# 5          -0.113623     0.297933
# 6           0.096204     0.457695
# 7          -0.065309     0.007643
# 8           0.025839     0.317694
# 9           0.178587    -0.259634
# 10          0.016790    -0.015198
# 11         -0.016128    -0.109778
# 12         -0.103976    -0.003676
# 13          0.177912     0.094095
# 14          0.015070    -0.267639
# 15          0.001514     0.250486
# 16          0.010227    -0.222580
# 17          0.036285     0.007243
# 18         -0.028719    -0.136394
# 19         -0.037334    -0.155085
# 20          0.001590    -0.141027
# 21          0.031286     0.191652
# 22          0.057038    -0.024171
# 23          0.053613     0.180795
# 24         -0.005425    -0.301093
# 25         -0.015635     0.081296
# 26          0.029807    -0.170636
# 27         -0.062850    -0.864135
# 28          0.148032    -0.114305
# 29         -0.018865     0.421536
# 30         -0.070218    -0.264099
# 31          0.047291    -0.049056
# 32         -0.023372     0.298375
# 33         -0.021008     0.206022
# 34          0.033060    -0.053237
# 35          0.060918     0.186371
# 36          0.081282     0.035456
# 37          0.084172     0.363912
# 38          0.092051     0.036552
# 39          0.028902     0.260057
# 40          0.059207     0.089994
# 41          0.013667    -0.082131
# 42          0.159410     0.277251
# 43          0.007160     0.178262
# 44          0.043018     0.051313
# 45          0.054652     0.142659
# 46          0.139372     0.269210
# 47          0.201701     0.196391
# 48          0.044945     0.011986
# 49          0.021398     0.002230
# 50          0.070800     0.147306
